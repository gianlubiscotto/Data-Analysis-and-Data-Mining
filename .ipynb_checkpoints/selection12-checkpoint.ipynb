# %%
import numpy as np
import pandas as pd
from sklearn.utils import shuffle
import matplotlib.pyplot as plt
import time
from sklearn import svm
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from scipy import stats
import statistics as stat
from sklearn.model_selection import KFold

# %%
ds=pd.read_csv("TrainingDataset.arff.txt",header=None, comment='@')

# %%
#feature selection (12/30)
corr= ds.corr().abs()
columns= np.full((corr.shape[0],),True, dtype=bool)
for i in range(corr.shape[0]):
    if corr.iloc[i,corr.shape[0]-1]<0.1:
        columns[i]=False 
        
selected_columns=ds.columns[columns]
ds= ds[selected_columns]   
print(np.shape(ds))
# Out:
# (11055, 13)

# %%
start_time= time.time()

C_range = np.logspace(-3 , 3, num=7)
Gamma_range = np.logspace(-3 , 3, num=7)
parameters = {'C':C_range, 'gamma':Gamma_range,'kernel':['rbf']}

train_scores_matrix = []
validation_scores_matrix = []
test_scores_matrix = []
best_estimators=[]
results=dict()

outer=KFold(n_splits=10)
outer.get_n_splits(ds)
count=0
for train_index, test_index in outer.split(ds):
    count+=1
    elapsed_time= time.time()
    print("\nIterazione",count)
    print("train+validation:", train_index, "test:", test_index)
    train_scores_c_perIter = []
    validation_scores_c_perIter = []
    test_scores_c_perIter = []
    
    X_train, X_test= ds.iloc[train_index,:np.shape(ds)[1]-1], ds.iloc[test_index,:np.shape(ds)[1]-1]
    Y_train, Y_test= ds.iloc[train_index,-1], ds.iloc[test_index,-1]
    #GridSearch con i parametri definiti sopra
    svc = svm.SVC()
    clf = GridSearchCV(svc, parameters, cv=10, scoring="accuracy",n_jobs=-1, return_train_score=True)
    clf.fit(X_train, Y_train)
    best_estimators.append(clf.best_params_)
    
    for i in range(0,len(clf.cv_results_['params'])):
        print ("Modello:",clf.cv_results_['params'][i], "accuracy:",clf.cv_results_['mean_test_score'][i])
    
    t_score= clf.score(X_test, Y_test)
    print ("Miglior modello:",clf.best_params_,"con score sul test set:",t_score)

    if str(clf.best_params_) in results:
        results[str(clf.best_params_)]['occurrency']+=1
        results[str(clf.best_params_)]['tests'].append(t_score)
    else:
        results[str(clf.best_params_)]=dict()
        results[str(clf.best_params_)]['occurrency']=1
        results[str(clf.best_params_)]['tests']=[]
        results[str(clf.best_params_)]['tests'].append(t_score)
    elapsed_time=time.time()-elapsed_time
    print("\nElapsed time:",elapsed_time)

'''
    # Draw heatmap of the validation accuracy as a function of gamma and C
    # The score are encoded as colors with the hot colormap which varies from dark
    # red to bright yellow. As the most interesting scores are all located in the
    # 0.92 to 0.97 range we use a custom normalizer to set the mid-point to 0.92 so
    # as to make it easier to visualize the small variations of score values in the
    # interesting range while not brutally collapsing all the low score values to
    # the same color.
    scores = clf.cv_results_['mean_test_score'].reshape(len(C_range),
                                                     len(Gamma_range))

    plt.figure(figsize=(5, 3))
    plt.subplots_adjust(left=.2, right=0.95, bottom=0.15, top=0.95)
    plt.imshow(scores, interpolation='nearest', cmap=plt.cm.hot,
               norm=MidpointNormalize(vmin=0.2, midpoint=0.92))
    plt.xlabel('gamma')
    plt.ylabel('C')
    plt.colorbar()
    plt.xticks(np.arange(len(Gamma_range)), Gamma_range, rotation=45)
    plt.yticks(np.arange(len(C_range)), C_range)
    plt.title('Validation accuracy')
    plt.show()
    
  
    
    ################    
    i=0
    maxdim=len(Gamma_range)
    while(i<len(clf.cv_results_['params'])):
        
        c=clf.cv_results_['params'][i]['C']

        train_scores_gamma_perC=[]
        validation_scores_gamma_perC=[]
        test_scores_gamma_perC=[]
        for j in range(i, i+maxdim):
            gamma=clf.cv_results_['params'][j]['gamma']
            validation_scores_gamma_perC.append(clf.cv_results_['mean_test_score'][j])  
            train_scores_gamma_perC.append(clf.cv_results_['mean_train_score'][j])
            
            temp_class = svm.SVC(kernel='rbf', C=c, gamma=gamma)
            temp_class.fit(X_train,Y_train)
            #n risultati sul test set 
            test_scores_gamma_perC.append(temp_class.score(X_test,Y_test))
        
        validation_scores_c_perIter.append(validation_scores_gamma_perC)
        train_scores_c_perIter.append(train_scores_gamma_perC)
        test_scores_c_perIter.append(test_scores_gamma_perC)

        i=i+maxdim
    #####################
    
    #train validation e test scores per ogni shuffle
    train_scores_matrix.append(train_scores_c_perIter)
    validation_scores_matrix.append(validation_scores_c_perIter)
    test_scores_matrix.append(test_scores_c_perIter)
   ''' 
    


elapsed_time=time.time()-start_time
print("\nTotal elapsed time:",elapsed_time)
# Out:
# Iterazione 1
# train+validation: [ 1106  1107  1108 ... 11052 11053 11054] test: [   0    1    2 ... 1103 1104 1105]
# Modello: {'C': 0.001, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.5570409086340335
# Modello: {'C': 0.001, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.5570409086340335
# Modello: {'C': 0.001, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.6301135792541964
# Modello: {'C': 0.001, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.5570409086340335
# Modello: {'C': 0.001, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.5570409086340335
# Modello: {'C': 0.001, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.5570409086340335
# Modello: {'C': 0.001, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.5570409086340335
# Modello: {'C': 0.01, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.5570409086340335
# Modello: {'C': 0.01, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.9048145542265554
# Modello: {'C': 0.01, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.9121519750728716
# Modello: {'C': 0.01, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.5570409086340335
# Modello: {'C': 0.01, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.5570409086340335
# Modello: {'C': 0.01, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.5570409086340335
# Modello: {'C': 0.01, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.5570409086340335
# Modello: {'C': 0.1, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.9051160920695547
# Modello: {'C': 0.1, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.9172781184038596
# Modello: {'C': 0.1, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.926726304151171
# Modello: {'C': 0.1, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.8953663684792441
# Modello: {'C': 0.1, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.7079103427480149
# Modello: {'C': 0.1, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.7079103427480149
# Modello: {'C': 0.1, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.7079103427480149
# Modello: {'C': 1.0, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.9174791436325259
# Modello: {'C': 1.0, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.9199919589908534
# Modello: {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.9382852547994773
# Modello: {'C': 1.0, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.9457231882601267
# Modello: {'C': 1.0, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.8969745703085737
# Modello: {'C': 1.0, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.8969745703085737
# Modello: {'C': 1.0, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.8969745703085737
# Modello: {'C': 10.0, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.9172781184038596
# Modello: {'C': 10.0, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.9295406573524977
# Modello: {'C': 10.0, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.9437129359734646
# Modello: {'C': 10.0, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.9451201125741281
# Modello: {'C': 10.0, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.8969745703085737
# Modello: {'C': 10.0, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.8969745703085737
# Modello: {'C': 10.0, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.8969745703085737
# Modello: {'C': 100.0, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.9200924716051865
# Modello: {'C': 100.0, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.936978590813147
# Modello: {'C': 100.0, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.9472308774751231
# Modello: {'C': 100.0, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.9451201125741281
# Modello: {'C': 100.0, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.8969745703085737
# Modello: {'C': 100.0, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.8969745703085737
# Modello: {'C': 100.0, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.8969745703085737
# Modello: {'C': 1000.0, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.9292391195094984
# Modello: {'C': 1000.0, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.9425067846014675
# Modello: {'C': 1000.0, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.9479344657754548
# Modello: {'C': 1000.0, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.9451201125741281
# Modello: {'C': 1000.0, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.8969745703085737
# Modello: {'C': 1000.0, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.8969745703085737
# Modello: {'C': 1000.0, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.8969745703085737
# Miglior modello: {'C': 1000.0, 'gamma': 0.1, 'kernel': 'rbf'} con score sul test set: 0.9602169981916817
#
# Elapsed time: 447.48875308036804
#
# Iterazione 2
# train+validation: [    0     1     2 ... 11052 11053 11054] test: [1106 1107 1108 ... 2209 2210 2211]
# Modello: {'C': 0.001, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.5560357824907026
# Modello: {'C': 0.001, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.5560357824907026
# Modello: {'C': 0.001, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.6373504874861795
# Modello: {'C': 0.001, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.5560357824907026
# Modello: {'C': 0.001, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.5560357824907026
# Modello: {'C': 0.001, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.5560357824907026
# Modello: {'C': 0.001, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.5560357824907026
# Modello: {'C': 0.01, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.5560357824907026
# Modello: {'C': 0.01, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.9047140416122224
# Modello: {'C': 0.01, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.9119509498442054
# Modello: {'C': 0.01, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.5560357824907026
# Modello: {'C': 0.01, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.5560357824907026
# Modello: {'C': 0.01, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.5560357824907026
# Modello: {'C': 0.01, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.5560357824907026
# Modello: {'C': 0.1, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.9047140416122224
# Modello: {'C': 0.1, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.916675042717861
# Modello: {'C': 0.1, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.9265252789225048
# Modello: {'C': 0.1, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.891144838677254
# Modello: {'C': 0.1, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.7125339230073374
# Modello: {'C': 0.1, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.7125339230073374
# Modello: {'C': 0.1, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.7125339230073374
# Modello: {'C': 1.0, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.9171776057895266
# Modello: {'C': 1.0, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.919589908533521
# Modello: {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.9376821791134787
# Modello: {'C': 1.0, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.9444165242737964
# Modello: {'C': 1.0, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.8997889235099005
# Modello: {'C': 1.0, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.8997889235099005
# Modello: {'C': 1.0, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.8997889235099005
# Modello: {'C': 10.0, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.9172781184038596
# Modello: {'C': 10.0, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.9295406573524977
# Modello: {'C': 10.0, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.9447180621167957
# Modello: {'C': 10.0, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.9443160116594632
# Modello: {'C': 10.0, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.8997889235099005
# Modello: {'C': 10.0, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.8997889235099005
# Modello: {'C': 10.0, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.8997889235099005
# Modello: {'C': 100.0, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.9209970851341843
# Modello: {'C': 100.0, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.936878078198814
# Modello: {'C': 100.0, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.9480349783897879
# Modello: {'C': 100.0, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.9443160116594632
# Modello: {'C': 100.0, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.8997889235099005
# Modello: {'C': 100.0, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.8997889235099005
# Modello: {'C': 100.0, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.8997889235099005
# Modello: {'C': 1000.0, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.9295406573524977
# Modello: {'C': 1000.0, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.9414011458438034
# Modello: {'C': 1000.0, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.9463262639461253
# Modello: {'C': 1000.0, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.9443160116594632
# Modello: {'C': 1000.0, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.8997889235099005
# Modello: {'C': 1000.0, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.8997889235099005
# Modello: {'C': 1000.0, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.8997889235099005
# Miglior modello: {'C': 100.0, 'gamma': 0.1, 'kernel': 'rbf'} con score sul test set: 0.9638336347197106
#
# Elapsed time: 421.6736054420471
#
# Iterazione 3
# train+validation: [    0     1     2 ... 11052 11053 11054] test: [2212 2213 2214 ... 3315 3316 3317]
# Modello: {'C': 0.001, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.5583475726203638
# Modello: {'C': 0.001, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.5583475726203638
# Modello: {'C': 0.001, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.6264951251382048
# Modello: {'C': 0.001, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.5583475726203638
# Modello: {'C': 0.001, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.5583475726203638
# Modello: {'C': 0.001, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.5583475726203638
# Modello: {'C': 0.001, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.5583475726203638
# Modello: {'C': 0.01, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.5583475726203638
# Modello: {'C': 0.01, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.9047140416122224
# Modello: {'C': 0.01, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.9121519750728716
# Modello: {'C': 0.01, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.5583475726203638
# Modello: {'C': 0.01, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.5583475726203638
# Modello: {'C': 0.01, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.5583475726203638
# Modello: {'C': 0.01, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.5583475726203638
# Modello: {'C': 0.1, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.9046135289978893
# Modello: {'C': 0.1, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.9159714544175294
# Modello: {'C': 0.1, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.9271283546085034
# Modello: {'C': 0.1, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.8946627801789124
# Modello: {'C': 0.1, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.7143431500653332
# Modello: {'C': 0.1, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.7143431500653332
# Modello: {'C': 0.1, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.7143431500653332
# Modello: {'C': 1.0, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.9162729922605287
# Modello: {'C': 1.0, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.9193888833048548
# Modello: {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.9366770529701478
# Modello: {'C': 1.0, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.9451201125741281
# Modello: {'C': 1.0, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.8864207458035983
# Modello: {'C': 1.0, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.8864207458035983
# Modello: {'C': 1.0, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.8864207458035983
# Modello: {'C': 10.0, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.9172781184038596
# Modello: {'C': 10.0, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.9285355312091668
# Modello: {'C': 10.0, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.9454216504171273
# Modello: {'C': 10.0, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.9451201125741281
# Modello: {'C': 10.0, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.8864207458035983
# Modello: {'C': 10.0, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.8864207458035983
# Modello: {'C': 10.0, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.8864207458035983
# Modello: {'C': 100.0, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.9206955472911851
# Modello: {'C': 100.0, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.9366770529701478
# Modello: {'C': 100.0, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.9493416423761182
# Modello: {'C': 100.0, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.9451201125741281
# Modello: {'C': 100.0, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.8864207458035983
# Modello: {'C': 100.0, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.8864207458035983
# Modello: {'C': 100.0, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.8864207458035983
# Modello: {'C': 1000.0, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.9280329681375012
# Modello: {'C': 1000.0, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.9432103729017992
# Modello: {'C': 1000.0, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.9480349783897879
# Modello: {'C': 1000.0, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.9451201125741281
# Modello: {'C': 1000.0, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.8864207458035983
# Modello: {'C': 1000.0, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.8864207458035983
# Modello: {'C': 1000.0, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.8864207458035983
# Miglior modello: {'C': 100.0, 'gamma': 0.1, 'kernel': 'rbf'} con score sul test set: 0.9575045207956601
#
# Elapsed time: 416.19687247276306
#
# Iterazione 4
# train+validation: [    0     1     2 ... 11052 11053 11054] test: [3318 3319 3320 ... 4421 4422 4423]
# Modello: {'C': 0.001, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.5573424464770329
# Modello: {'C': 0.001, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.5573424464770329
# Modello: {'C': 0.001, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.6314202432405267
# Modello: {'C': 0.001, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.5573424464770329
# Modello: {'C': 0.001, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.5573424464770329
# Modello: {'C': 0.001, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.5573424464770329
# Modello: {'C': 0.001, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.5573424464770329
# Modello: {'C': 0.01, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.5573424464770329
# Modello: {'C': 0.01, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.904412503769223
# Modello: {'C': 0.01, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.9121519750728716
# Modello: {'C': 0.01, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.5573424464770329
# Modello: {'C': 0.01, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.5573424464770329
# Modello: {'C': 0.01, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.5573424464770329
# Modello: {'C': 0.01, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.5573424464770329
# Modello: {'C': 0.1, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.9041109659262238
# Modello: {'C': 0.1, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.9169765805608604
# Modello: {'C': 0.1, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.926726304151171
# Modello: {'C': 0.1, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.8908433008342547
# Modello: {'C': 0.1, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.7139410996080008
# Modello: {'C': 0.1, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.7139410996080008
# Modello: {'C': 0.1, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.7139410996080008
# Modello: {'C': 1.0, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.9172781184038596
# Modello: {'C': 1.0, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.919690421147854
# Modello: {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.9372801286561463
# Modello: {'C': 1.0, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.9467283144034576
# Modello: {'C': 1.0, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.9006935370388984
# Modello: {'C': 1.0, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.9007940496532315
# Modello: {'C': 1.0, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.8968740576942407
# Modello: {'C': 10.0, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.9164740174891949
# Modello: {'C': 10.0, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.9290380942808323
# Modello: {'C': 10.0, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.9451201125741281
# Modello: {'C': 10.0, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.9468288270177907
# Modello: {'C': 10.0, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.9006935370388984
# Modello: {'C': 10.0, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.9007940496532315
# Modello: {'C': 10.0, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.8968740576942407
# Modello: {'C': 100.0, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.921700673434516
# Modello: {'C': 100.0, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.9364760277414815
# Modello: {'C': 100.0, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.9506483063624485
# Modello: {'C': 100.0, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.9468288270177907
# Modello: {'C': 100.0, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.9006935370388984
# Modello: {'C': 100.0, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.9007940496532315
# Modello: {'C': 100.0, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.8968740576942407
# Modello: {'C': 1000.0, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.9296411699668309
# Modello: {'C': 1000.0, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.9415016584581365
# Modello: {'C': 1000.0, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.9500452306764499
# Modello: {'C': 1000.0, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.9468288270177907
# Modello: {'C': 1000.0, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.9006935370388984
# Modello: {'C': 1000.0, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.9007940496532315
# Modello: {'C': 1000.0, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.8968740576942407
# Miglior modello: {'C': 100.0, 'gamma': 0.1, 'kernel': 'rbf'} con score sul test set: 0.9584086799276673
#
# Elapsed time: 406.9254014492035
#
# Iterazione 5
# train+validation: [    0     1     2 ... 11052 11053 11054] test: [4424 4425 4426 ... 5527 5528 5529]
# C:\Users\Chiara\Anaconda3\lib\site-packages\sklearn\externals\joblib\externals\loky\process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# Modello: {'C': 0.001, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.554427580661373
# Modello: {'C': 0.001, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.554427580661373
# Modello: {'C': 0.001, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.641974067745502
# Modello: {'C': 0.001, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.554427580661373
# Modello: {'C': 0.001, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.554427580661373
# Modello: {'C': 0.001, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.554427580661373
# Modello: {'C': 0.001, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.554427580661373
# Modello: {'C': 0.01, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.554427580661373
# Modello: {'C': 0.01, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.905417629912554
# Modello: {'C': 0.01, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.9121519750728716
# Modello: {'C': 0.01, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.554427580661373
# Modello: {'C': 0.01, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.554427580661373
# Modello: {'C': 0.01, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.554427580661373
# Modello: {'C': 0.01, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.554427580661373
# Modello: {'C': 0.1, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.9055181425268871
# Modello: {'C': 0.1, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.9169765805608604
# Modello: {'C': 0.1, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.9270278419941703
# Modello: {'C': 0.1, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.8973766207659061
# Modello: {'C': 0.1, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.7205749321539853
# Modello: {'C': 0.1, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.7205749321539853
# Modello: {'C': 0.1, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.7205749321539853
# Modello: {'C': 1.0, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.9169765805608604
# Modello: {'C': 1.0, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.919690421147854
# Modello: {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.9362750025128154
# Modello: {'C': 1.0, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.9480349783897879
# Modello: {'C': 1.0, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.9027037893255604
# Modello: {'C': 1.0, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.9027037893255604
# Modello: {'C': 1.0, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.9027037893255604
# Modello: {'C': 10.0, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.9178811940898582
# Modello: {'C': 10.0, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.9280329681375012
# Modello: {'C': 10.0, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.9464267765604584
# Modello: {'C': 10.0, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.9476329279324556
# Modello: {'C': 10.0, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.9027037893255604
# Modello: {'C': 10.0, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.9027037893255604
# Modello: {'C': 10.0, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.9027037893255604
# Modello: {'C': 100.0, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.9201929842195196
# Modello: {'C': 100.0, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.9373806412704795
# Modello: {'C': 100.0, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.9483365162327873
# Modello: {'C': 100.0, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.9476329279324556
# Modello: {'C': 100.0, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.9027037893255604
# Modello: {'C': 100.0, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.9027037893255604
# Modello: {'C': 100.0, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.9027037893255604
# Modello: {'C': 1000.0, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.9278319429088351
# Modello: {'C': 1000.0, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.9458237008744598
# Modello: {'C': 1000.0, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.9484370288471203
# Modello: {'C': 1000.0, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.9476329279324556
# Modello: {'C': 1000.0, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.9027037893255604
# Modello: {'C': 1000.0, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.9027037893255604
# Modello: {'C': 1000.0, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.9027037893255604
# Miglior modello: {'C': 1000.0, 'gamma': 0.1, 'kernel': 'rbf'} con score sul test set: 0.9602169981916817
#
# Elapsed time: 411.08773255348206
#
# Iterazione 6
# train+validation: [    0     1     2 ... 11052 11053 11054] test: [5530 5531 5532 ... 6632 6633 6634]
# C:\Users\Chiara\Anaconda3\lib\site-packages\sklearn\externals\joblib\externals\loky\process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# Modello: {'C': 0.001, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.5593969849246231
# Modello: {'C': 0.001, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.5593969849246231
# Modello: {'C': 0.001, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.6353768844221106
# Modello: {'C': 0.001, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.5593969849246231
# Modello: {'C': 0.001, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.5593969849246231
# Modello: {'C': 0.001, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.5593969849246231
# Modello: {'C': 0.001, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.5593969849246231
# Modello: {'C': 0.01, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.5593969849246231
# Modello: {'C': 0.01, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.9036180904522613
# Modello: {'C': 0.01, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.9104522613065327
# Modello: {'C': 0.01, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.5593969849246231
# Modello: {'C': 0.01, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.5593969849246231
# Modello: {'C': 0.01, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.5593969849246231
# Modello: {'C': 0.01, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.5593969849246231
# Modello: {'C': 0.1, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.9033165829145728
# Modello: {'C': 0.1, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.9141708542713568
# Modello: {'C': 0.1, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.9255276381909547
# Modello: {'C': 0.1, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.8964824120603015
# Modello: {'C': 0.1, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.7283417085427135
# Modello: {'C': 0.1, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.7283417085427135
# Modello: {'C': 0.1, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.7283417085427135
# Modello: {'C': 1.0, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.915175879396985
# Modello: {'C': 1.0, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.9178894472361809
# Modello: {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.9353768844221105
# Modello: {'C': 1.0, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.9474371859296482
# Modello: {'C': 1.0, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.8858291457286432
# Modello: {'C': 1.0, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.8858291457286432
# Modello: {'C': 1.0, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.8858291457286432
# Modello: {'C': 10.0, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.9162814070351759
# Modello: {'C': 10.0, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.9278391959798995
# Modello: {'C': 10.0, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.9457286432160804
# Modello: {'C': 10.0, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.9477386934673366
# Modello: {'C': 10.0, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.8858291457286432
# Modello: {'C': 10.0, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.8858291457286432
# Modello: {'C': 10.0, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.8858291457286432
# Modello: {'C': 100.0, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.9170854271356784
# Modello: {'C': 100.0, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.9370854271356784
# Modello: {'C': 100.0, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.949748743718593
# Modello: {'C': 100.0, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.9477386934673366
# Modello: {'C': 100.0, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.8858291457286432
# Modello: {'C': 100.0, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.8858291457286432
# Modello: {'C': 100.0, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.8858291457286432
# Modello: {'C': 1000.0, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.9279396984924623
# Modello: {'C': 1000.0, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.9417085427135679
# Modello: {'C': 1000.0, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.9482412060301507
# Modello: {'C': 1000.0, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.9477386934673366
# Modello: {'C': 1000.0, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.8858291457286432
# Modello: {'C': 1000.0, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.8858291457286432
# Modello: {'C': 1000.0, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.8858291457286432
# Miglior modello: {'C': 100.0, 'gamma': 0.1, 'kernel': 'rbf'} con score sul test set: 0.9583710407239819
#
# Elapsed time: 398.1507008075714
#
# Iterazione 7
# train+validation: [    0     1     2 ... 11052 11053 11054] test: [6635 6636 6637 ... 7737 7738 7739]
# C:\Users\Chiara\Anaconda3\lib\site-packages\sklearn\externals\joblib\externals\loky\process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# Modello: {'C': 0.001, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.5566834170854271
# Modello: {'C': 0.001, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.5566834170854271
# Modello: {'C': 0.001, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.6413065326633166
# Modello: {'C': 0.001, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.5566834170854271
# Modello: {'C': 0.001, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.5566834170854271
# Modello: {'C': 0.001, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.5566834170854271
# Modello: {'C': 0.001, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.5566834170854271
# Modello: {'C': 0.01, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.5566834170854271
# Modello: {'C': 0.01, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.9045226130653267
# Modello: {'C': 0.01, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.9114572864321608
# Modello: {'C': 0.01, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.5566834170854271
# Modello: {'C': 0.01, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.5566834170854271
# Modello: {'C': 0.01, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.5566834170854271
# Modello: {'C': 0.01, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.5566834170854271
# Modello: {'C': 0.1, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.904321608040201
# Modello: {'C': 0.1, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.9159798994974875
# Modello: {'C': 0.1, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.9273366834170854
# Modello: {'C': 0.1, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.8973869346733668
# Modello: {'C': 0.1, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.7348743718592965
# Modello: {'C': 0.1, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.7348743718592965
# Modello: {'C': 0.1, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.7348743718592965
# Modello: {'C': 1.0, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.9164824120603015
# Modello: {'C': 1.0, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.9198994974874372
# Modello: {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.9371859296482412
# Modello: {'C': 1.0, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.9494472361809045
# Modello: {'C': 1.0, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.8950753768844221
# Modello: {'C': 1.0, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.8950753768844221
# Modello: {'C': 1.0, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.8950753768844221
# Modello: {'C': 10.0, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.917286432160804
# Modello: {'C': 10.0, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.9294472361809045
# Modello: {'C': 10.0, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.9476381909547739
# Modello: {'C': 10.0, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.9483417085427136
# Modello: {'C': 10.0, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.8950753768844221
# Modello: {'C': 10.0, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.8950753768844221
# Modello: {'C': 10.0, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.8950753768844221
# Modello: {'C': 100.0, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.9196984924623116
# Modello: {'C': 100.0, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.9393969849246231
# Modello: {'C': 100.0, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.9525628140703517
# Modello: {'C': 100.0, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.9483417085427136
# Modello: {'C': 100.0, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.8950753768844221
# Modello: {'C': 100.0, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.8950753768844221
# Modello: {'C': 100.0, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.8950753768844221
# Modello: {'C': 1000.0, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.9299497487437186
# Modello: {'C': 1000.0, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.9446231155778895
# Modello: {'C': 1000.0, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.9514572864321608
# Modello: {'C': 1000.0, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.9483417085427136
# Modello: {'C': 1000.0, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.8950753768844221
# Modello: {'C': 1000.0, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.8950753768844221
# Modello: {'C': 1000.0, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.8950753768844221
# Miglior modello: {'C': 100.0, 'gamma': 0.1, 'kernel': 'rbf'} con score sul test set: 0.9339366515837104
#
# Elapsed time: 398.86432099342346
#
# Iterazione 8
# train+validation: [    0     1     2 ... 11052 11053 11054] test: [7740 7741 7742 ... 8842 8843 8844]
# Modello: {'C': 0.001, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.556180904522613
# Modello: {'C': 0.001, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.556180904522613
# Modello: {'C': 0.001, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.6541708542713568
# Modello: {'C': 0.001, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.556180904522613
# Modello: {'C': 0.001, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.556180904522613
# Modello: {'C': 0.001, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.556180904522613
# Modello: {'C': 0.001, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.556180904522613
# Modello: {'C': 0.01, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.556180904522613
# Modello: {'C': 0.01, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.9056281407035176
# Modello: {'C': 0.01, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.9149748743718593
# Modello: {'C': 0.01, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.5562814070351759
# Modello: {'C': 0.01, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.556180904522613
# Modello: {'C': 0.01, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.556180904522613
# Modello: {'C': 0.01, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.556180904522613
# Modello: {'C': 0.1, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.9061306532663317
# Modello: {'C': 0.1, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.9191959798994975
# Modello: {'C': 0.1, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.9284422110552764
# Modello: {'C': 0.1, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.9029145728643216
# Modello: {'C': 0.1, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.7298492462311558
# Modello: {'C': 0.1, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.7298492462311558
# Modello: {'C': 0.1, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.7298492462311558
# Modello: {'C': 1.0, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.9193969849246231
# Modello: {'C': 1.0, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.9213065326633166
# Modello: {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.9398994974874372
# Modello: {'C': 1.0, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.9512562814070352
# Modello: {'C': 1.0, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.8980904522613066
# Modello: {'C': 1.0, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.8980904522613066
# Modello: {'C': 1.0, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.8980904522613066
# Modello: {'C': 10.0, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.9197989949748744
# Modello: {'C': 10.0, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.929748743718593
# Modello: {'C': 10.0, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.9492462311557789
# Modello: {'C': 10.0, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.9507537688442211
# Modello: {'C': 10.0, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.8980904522613066
# Modello: {'C': 10.0, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.8980904522613066
# Modello: {'C': 10.0, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.8980904522613066
# Modello: {'C': 100.0, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.9214070351758794
# Modello: {'C': 100.0, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.9391959798994974
# Modello: {'C': 100.0, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.9528643216080402
# Modello: {'C': 100.0, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.9507537688442211
# Modello: {'C': 100.0, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.8980904522613066
# Modello: {'C': 100.0, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.8980904522613066
# Modello: {'C': 100.0, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.8980904522613066
# Modello: {'C': 1000.0, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.9298492462311557
# Modello: {'C': 1000.0, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.9447236180904522
# Modello: {'C': 1000.0, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.9521608040201005
# Modello: {'C': 1000.0, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.9507537688442211
# Modello: {'C': 1000.0, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.8980904522613066
# Modello: {'C': 1000.0, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.8980904522613066
# Modello: {'C': 1000.0, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.8980904522613066
# Miglior modello: {'C': 100.0, 'gamma': 0.1, 'kernel': 'rbf'} con score sul test set: 0.9266968325791856
#
# Elapsed time: 393.6318693161011
#
# Iterazione 9
# train+validation: [    0     1     2 ... 11052 11053 11054] test: [8845 8846 8847 ... 9947 9948 9949]
# C:\Users\Chiara\Anaconda3\lib\site-packages\sklearn\externals\joblib\externals\loky\process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# Modello: {'C': 0.001, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.5576884422110553
# Modello: {'C': 0.001, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.5576884422110553
# Modello: {'C': 0.001, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.6528643216080402
# Modello: {'C': 0.001, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.5576884422110553
# Modello: {'C': 0.001, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.5576884422110553
# Modello: {'C': 0.001, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.5576884422110553
# Modello: {'C': 0.001, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.5576884422110553
# Modello: {'C': 0.01, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.5576884422110553
# Modello: {'C': 0.01, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.9013065326633166
# Modello: {'C': 0.01, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.911356783919598
# Modello: {'C': 0.01, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.558391959798995
# Modello: {'C': 0.01, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.5576884422110553
# Modello: {'C': 0.01, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.5576884422110553
# Modello: {'C': 0.01, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.5576884422110553
# Modello: {'C': 0.1, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.901608040201005
# Modello: {'C': 0.1, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.9157788944723618
# Modello: {'C': 0.1, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.9262311557788945
# Modello: {'C': 0.1, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.8955778894472362
# Modello: {'C': 0.1, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.7303517587939699
# Modello: {'C': 0.1, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.7303517587939699
# Modello: {'C': 0.1, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.7303517587939699
# Modello: {'C': 1.0, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.9162814070351759
# Modello: {'C': 1.0, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.9195979899497487
# Modello: {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.9385929648241206
# Modello: {'C': 1.0, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.9466331658291457
# Modello: {'C': 1.0, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.8905527638190954
# Modello: {'C': 1.0, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.8905527638190954
# Modello: {'C': 1.0, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.8905527638190954
# Modello: {'C': 10.0, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.9188944723618091
# Modello: {'C': 10.0, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.9274371859296482
# Modello: {'C': 10.0, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.9453266331658291
# Modello: {'C': 10.0, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.9463316582914573
# Modello: {'C': 10.0, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.8905527638190954
# Modello: {'C': 10.0, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.8905527638190954
# Modello: {'C': 10.0, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.8905527638190954
# Modello: {'C': 100.0, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.92
# Modello: {'C': 100.0, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.9377889447236181
# Modello: {'C': 100.0, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.9504522613065327
# Modello: {'C': 100.0, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.9463316582914573
# Modello: {'C': 100.0, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.8905527638190954
# Modello: {'C': 100.0, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.8905527638190954
# Modello: {'C': 100.0, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.8905527638190954
# Modello: {'C': 1000.0, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.9276381909547738
# Modello: {'C': 1000.0, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.942713567839196
# Modello: {'C': 1000.0, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.9503517587939698
# Modello: {'C': 1000.0, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.9463316582914573
# Modello: {'C': 1000.0, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.8905527638190954
# Modello: {'C': 1000.0, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.8905527638190954
# Modello: {'C': 1000.0, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.8905527638190954
# Miglior modello: {'C': 100.0, 'gamma': 0.1, 'kernel': 'rbf'} con score sul test set: 0.9402714932126697
#
# Elapsed time: 395.773246049881
#
# Iterazione 10
# train+validation: [   0    1    2 ... 9947 9948 9949] test: [ 9950  9951  9952 ... 11052 11053 11054]
# Modello: {'C': 0.001, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.5562814070351759
# Modello: {'C': 0.001, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.5562814070351759
# Modello: {'C': 0.001, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.6597989949748744
# Modello: {'C': 0.001, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.5562814070351759
# Modello: {'C': 0.001, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.5562814070351759
# Modello: {'C': 0.001, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.5562814070351759
# Modello: {'C': 0.001, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.5562814070351759
# Modello: {'C': 0.01, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.5562814070351759
# Modello: {'C': 0.01, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.9013065326633166
# Modello: {'C': 0.01, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.9115577889447236
# Modello: {'C': 0.01, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.557286432160804
# Modello: {'C': 0.01, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.5562814070351759
# Modello: {'C': 0.01, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.5562814070351759
# Modello: {'C': 0.01, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.5562814070351759
# Modello: {'C': 0.1, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.9018090452261307
# Modello: {'C': 0.1, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.9165829145728643
# Modello: {'C': 0.1, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.925929648241206
# Modello: {'C': 0.1, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.8954773869346734
# Modello: {'C': 0.1, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.7301507537688442
# Modello: {'C': 0.1, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.7301507537688442
# Modello: {'C': 0.1, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.7301507537688442
# Modello: {'C': 1.0, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.9157788944723618
# Modello: {'C': 1.0, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.9192964824120603
# Modello: {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.9368844221105528
# Modello: {'C': 1.0, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.9457286432160804
# Modello: {'C': 1.0, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.902713567839196
# Modello: {'C': 1.0, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.902713567839196
# Modello: {'C': 1.0, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.902713567839196
# Modello: {'C': 10.0, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.9184924623115578
# Modello: {'C': 10.0, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.9269346733668342
# Modello: {'C': 10.0, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.9445226130653266
# Modello: {'C': 10.0, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.9456281407035176
# Modello: {'C': 10.0, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.902713567839196
# Modello: {'C': 10.0, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.902713567839196
# Modello: {'C': 10.0, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.902713567839196
# Modello: {'C': 100.0, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.9188944723618091
# Modello: {'C': 100.0, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.9358793969849246
# Modello: {'C': 100.0, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.9487437185929648
# Modello: {'C': 100.0, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.9456281407035176
# Modello: {'C': 100.0, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.902713567839196
# Modello: {'C': 100.0, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.902713567839196
# Modello: {'C': 100.0, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.902713567839196
# Modello: {'C': 1000.0, 'gamma': 0.001, 'kernel': 'rbf'} accuracy: 0.9272361809045226
# Modello: {'C': 1000.0, 'gamma': 0.01, 'kernel': 'rbf'} accuracy: 0.942713567839196
# Modello: {'C': 1000.0, 'gamma': 0.1, 'kernel': 'rbf'} accuracy: 0.9478391959798995
# Modello: {'C': 1000.0, 'gamma': 1.0, 'kernel': 'rbf'} accuracy: 0.9456281407035176
# Modello: {'C': 1000.0, 'gamma': 10.0, 'kernel': 'rbf'} accuracy: 0.902713567839196
# Modello: {'C': 1000.0, 'gamma': 100.0, 'kernel': 'rbf'} accuracy: 0.902713567839196
# Modello: {'C': 1000.0, 'gamma': 1000.0, 'kernel': 'rbf'} accuracy: 0.902713567839196
# Miglior modello: {'C': 100.0, 'gamma': 0.1, 'kernel': 'rbf'} con score sul test set: 0.9493212669683257
#
# Elapsed time: 399.2111167907715
#
# Total elapsed time: 4089.0046265125275

# %%
print(results,"\n")
flag=False
duplicates=[]
tot=0
for x in results:
    tot=tot+results[x]['occurrency']
occ=0
best=None
for key in results:
    if results[key]['occurrency']>occ:
        occ=results[key]['occurrency']
        best=key
        testscores=results[key]['tests']
    elif results[key]['occurrency']==occ:
        flag=True
        duplicates.append(key)
print(best,"occorre",occ,"volte su",tot,".\nMedia dei test score:",np.mean(testscores))
if flag:
    print("Ci sono più modelli con la stessa occorrenza:")
    for x in duplicates:
        print(x,"occorre",results[x]['occurrency'],"volte su",tot,".\nMedia dei test score:",np.mean(results[x]['tests']))
# Out:
# {"{'C': 1000.0, 'gamma': 0.1, 'kernel': 'rbf'}": {'occurrency': 2, 'tests': [0.9602169981916817, 0.9602169981916817]}, "{'C': 100.0, 'gamma': 0.1, 'kernel': 'rbf'}": {'occurrency': 8, 'tests': [0.9638336347197106, 0.9575045207956601, 0.9584086799276673, 0.9583710407239819, 0.9339366515837104, 0.9266968325791856, 0.9402714932126697, 0.9493212669683257]}}
#
# {'C': 100.0, 'gamma': 0.1, 'kernel': 'rbf'} occorre 8 volte su 10 .
# Media dei test score: 0.948543015063864

# %%
print(np.var([0.9638336347197106, 0.9575045207956601, 0.9584086799276673, 0.9583710407239819, 0.9339366515837104, 0.9266968325791856, 0.9402714932126697, 0.9493212669683257]))
# Out:
# 0.00015845729488142695

# %%
start_time= time.time()

C_range = np.logspace(-3 , 3, num=7)
parameters = {'C':C_range, 'kernel':['linear']}
train_scores_matrix = []
validation_scores_matrix = []
test_scores_matrix = []
best_estimators=[]
results=dict()

outer=KFold(n_splits=10)
outer.get_n_splits(ds)
count=0
for train_index, test_index in outer.split(ds):
    count+=1
    elapsed_time= time.time()
    print("\nIterazione",count)
    print("train+validation:", train_index, "test:", test_index)
    train_scores=[]
    validation_scores=[]
    test_scores=[]
    X_train, X_test= ds.iloc[train_index,:np.shape(ds)[1]-1], ds.iloc[test_index,:np.shape(ds)[1]-1]
    Y_train, Y_test= ds.iloc[train_index,-1], ds.iloc[test_index,-1]
    #GridSearch con i parametri definiti sopra
    svc = svm.SVC()
    clf = GridSearchCV(svc, parameters, cv=10, scoring="accuracy",n_jobs=-1, return_train_score=True)
    clf.fit(X_train, Y_train)
    best_estimators.append(clf.best_params_)
    
    for i in range(0,len(clf.cv_results_['params'])):
        print ("Modello:",clf.cv_results_['params'][i], "accuracy:",clf.cv_results_['mean_test_score'][i])
        
    t_score= clf.score(X_test, Y_test)
    print ("Miglior modello:",clf.best_params_,"con score sul test set:",t_score)

    if str(clf.best_params_) in results:
        results[str(clf.best_params_)]['occurrency']+=1
        results[str(clf.best_params_)]['tests'].append(t_score)
    else:
        results[str(clf.best_params_)]=dict()
        results[str(clf.best_params_)]['occurrency']=1
        results[str(clf.best_params_)]['tests']=[]
        results[str(clf.best_params_)]['tests'].append(t_score)
    
    '''
    #combinazioni di parametri
    hyperparameters = []
    for i in clf.cv_results_['params']:
        hyperparameters.append(i)
    
    #score sul test set per ogni combinazione
    for i in hyperparameters:
        temp_class = svm.SVC(kernel=i['kernel'],C=i['C'])
        temp_class.fit(X_train,Y_train)
        #n risultati sul test set 
        test_scores.append(temp_class.score(X_test,Y_test))
        
    for i in range (0,len(clf.cv_results_['mean_test_score'])): 
        train_scores.append(clf.cv_results_['mean_train_score'][i])
        validation_scores.append(clf.cv_results_['mean_test_score'][i])  
    
    #train validation e test scores per ogni iterazione
    train_scores_matrix.append(train_scores)
    validation_scores_matrix.append(validation_scores)
    test_scores_matrix.append(test_scores)
    '''
    elapsed_time=time.time()-elapsed_time
    print("\nElapsed time:",elapsed_time)


elapsed_time=time.time()-start_time
print("\nTotal elapsed time:",elapsed_time)
# Out:
# Iterazione 1
# train+validation: [ 1106  1107  1108 ... 11052 11053 11054] test: [   0    1    2 ... 1103 1104 1105]
# Modello: {'C': 0.001, 'kernel': 'linear'} accuracy: 0.9133581264448688
# Modello: {'C': 0.01, 'kernel': 'linear'} accuracy: 0.9170770931751935
# Modello: {'C': 0.1, 'kernel': 'linear'} accuracy: 0.9172781184038596
# Modello: {'C': 1.0, 'kernel': 'linear'} accuracy: 0.9182832445471907
# Modello: {'C': 10.0, 'kernel': 'linear'} accuracy: 0.9182832445471907
# Modello: {'C': 100.0, 'kernel': 'linear'} accuracy: 0.9182832445471907
# Modello: {'C': 1000.0, 'kernel': 'linear'} accuracy: 0.9182832445471907
# Miglior modello: {'C': 1.0, 'kernel': 'linear'} con score sul test set: 0.9159132007233273
#
# Elapsed time: 218.11855792999268
#
# Iterazione 2
# train+validation: [    0     1     2 ... 11052 11053 11054] test: [1106 1107 1108 ... 2209 2210 2211]
# Modello: {'C': 0.001, 'kernel': 'linear'} accuracy: 0.9136596642878682
# Modello: {'C': 0.01, 'kernel': 'linear'} accuracy: 0.9170770931751935
# Modello: {'C': 0.1, 'kernel': 'linear'} accuracy: 0.9169765805608604
# Modello: {'C': 1.0, 'kernel': 'linear'} accuracy: 0.9178811940898582
# Modello: {'C': 10.0, 'kernel': 'linear'} accuracy: 0.9178811940898582
# Modello: {'C': 100.0, 'kernel': 'linear'} accuracy: 0.9178811940898582
# Modello: {'C': 1000.0, 'kernel': 'linear'} accuracy: 0.9178811940898582
# Miglior modello: {'C': 1.0, 'kernel': 'linear'} con score sul test set: 0.9177215189873418
#
# Elapsed time: 215.65046572685242
#
# Iterazione 3
# train+validation: [    0     1     2 ... 11052 11053 11054] test: [2212 2213 2214 ... 3315 3316 3317]
# Modello: {'C': 0.001, 'kernel': 'linear'} accuracy: 0.9131571012162026
# Modello: {'C': 0.01, 'kernel': 'linear'} accuracy: 0.9173786310181928
# Modello: {'C': 0.1, 'kernel': 'linear'} accuracy: 0.9172781184038596
# Modello: {'C': 1.0, 'kernel': 'linear'} accuracy: 0.9179817067041913
# Modello: {'C': 10.0, 'kernel': 'linear'} accuracy: 0.9178811940898582
# Modello: {'C': 100.0, 'kernel': 'linear'} accuracy: 0.9178811940898582
# Modello: {'C': 1000.0, 'kernel': 'linear'} accuracy: 0.9178811940898582
# Miglior modello: {'C': 1.0, 'kernel': 'linear'} con score sul test set: 0.9213381555153707
#
# Elapsed time: 221.22448301315308
#
# Iterazione 4
# train+validation: [    0     1     2 ... 11052 11053 11054] test: [3318 3319 3320 ... 4421 4422 4423]
# Modello: {'C': 0.001, 'kernel': 'linear'} accuracy: 0.9131571012162026
# Modello: {'C': 0.01, 'kernel': 'linear'} accuracy: 0.9171776057895266
# Modello: {'C': 0.1, 'kernel': 'linear'} accuracy: 0.9170770931751935
# Modello: {'C': 1.0, 'kernel': 'linear'} accuracy: 0.9174791436325259
# Modello: {'C': 10.0, 'kernel': 'linear'} accuracy: 0.9177806814755252
# Modello: {'C': 100.0, 'kernel': 'linear'} accuracy: 0.9177806814755252
# Modello: {'C': 1000.0, 'kernel': 'linear'} accuracy: 0.9173786310181928
# Miglior modello: {'C': 10.0, 'kernel': 'linear'} con score sul test set: 0.9222423146473779
#
# Elapsed time: 246.5496814250946
#
# Iterazione 5
# train+validation: [    0     1     2 ... 11052 11053 11054] test: [4424 4425 4426 ... 5527 5528 5529]
# Modello: {'C': 0.001, 'kernel': 'linear'} accuracy: 0.9142627399738668
# Modello: {'C': 0.01, 'kernel': 'linear'} accuracy: 0.9169765805608604
# Modello: {'C': 0.1, 'kernel': 'linear'} accuracy: 0.9156699165745301
# Modello: {'C': 1.0, 'kernel': 'linear'} accuracy: 0.9169765805608604
# Modello: {'C': 10.0, 'kernel': 'linear'} accuracy: 0.916574530103528
# Modello: {'C': 100.0, 'kernel': 'linear'} accuracy: 0.9167755553321942
# Modello: {'C': 1000.0, 'kernel': 'linear'} accuracy: 0.9170770931751935
# Miglior modello: {'C': 1000.0, 'kernel': 'linear'} con score sul test set: 0.9041591320072333
#
# Elapsed time: 451.17602252960205
#
# Iterazione 6
# train+validation: [    0     1     2 ... 11052 11053 11054] test: [5530 5531 5532 ... 6632 6633 6634]
# Modello: {'C': 0.001, 'kernel': 'linear'} accuracy: 0.912964824120603
# Modello: {'C': 0.01, 'kernel': 'linear'} accuracy: 0.9149748743718593
# Modello: {'C': 0.1, 'kernel': 'linear'} accuracy: 0.9156783919597989
# Modello: {'C': 1.0, 'kernel': 'linear'} accuracy: 0.9159798994974875
# Modello: {'C': 10.0, 'kernel': 'linear'} accuracy: 0.9160804020100503
# Modello: {'C': 100.0, 'kernel': 'linear'} accuracy: 0.9162814070351759
# Modello: {'C': 1000.0, 'kernel': 'linear'} accuracy: 0.9160804020100503
# Miglior modello: {'C': 100.0, 'kernel': 'linear'} con score sul test set: 0.9266968325791856
#
# Elapsed time: 416.19436049461365
#
# Iterazione 7
# train+validation: [    0     1     2 ... 11052 11053 11054] test: [6635 6636 6637 ... 7737 7738 7739]
# Modello: {'C': 0.001, 'kernel': 'linear'} accuracy: 0.9134673366834171
# Modello: {'C': 0.01, 'kernel': 'linear'} accuracy: 0.9165829145728643
# Modello: {'C': 0.1, 'kernel': 'linear'} accuracy: 0.917788944723618
# Modello: {'C': 1.0, 'kernel': 'linear'} accuracy: 0.9178894472361809
# Modello: {'C': 10.0, 'kernel': 'linear'} accuracy: 0.9176884422110553
# Modello: {'C': 100.0, 'kernel': 'linear'} accuracy: 0.9179899497487437
# Modello: {'C': 1000.0, 'kernel': 'linear'} accuracy: 0.917788944723618
# Miglior modello: {'C': 100.0, 'kernel': 'linear'} con score sul test set: 0.9230769230769231
#
# Elapsed time: 480.9841184616089
#
# Iterazione 8
# train+validation: [    0     1     2 ... 11052 11053 11054] test: [7740 7741 7742 ... 8842 8843 8844]
# Modello: {'C': 0.001, 'kernel': 'linear'} accuracy: 0.916180904522613
# Modello: {'C': 0.01, 'kernel': 'linear'} accuracy: 0.9188944723618091
# Modello: {'C': 0.1, 'kernel': 'linear'} accuracy: 0.9184924623115578
# Modello: {'C': 1.0, 'kernel': 'linear'} accuracy: 0.92
# Modello: {'C': 10.0, 'kernel': 'linear'} accuracy: 0.9202010050251256
# Modello: {'C': 100.0, 'kernel': 'linear'} accuracy: 0.9202010050251256
# Modello: {'C': 1000.0, 'kernel': 'linear'} accuracy: 0.9203015075376885
# Miglior modello: {'C': 1000.0, 'kernel': 'linear'} con score sul test set: 0.8995475113122172
#
# Elapsed time: 287.1056308746338
#
# Iterazione 9
# train+validation: [    0     1     2 ... 11052 11053 11054] test: [8845 8846 8847 ... 9947 9948 9949]
# Modello: {'C': 0.001, 'kernel': 'linear'} accuracy: 0.9120603015075377
# Modello: {'C': 0.01, 'kernel': 'linear'} accuracy: 0.9168844221105528
# Modello: {'C': 0.1, 'kernel': 'linear'} accuracy: 0.9178894472361809
# Modello: {'C': 1.0, 'kernel': 'linear'} accuracy: 0.9178894472361809
# Modello: {'C': 10.0, 'kernel': 'linear'} accuracy: 0.9176884422110553
# Modello: {'C': 100.0, 'kernel': 'linear'} accuracy: 0.917788944723618
# Modello: {'C': 1000.0, 'kernel': 'linear'} accuracy: 0.917788944723618
# Miglior modello: {'C': 0.1, 'kernel': 'linear'} con score sul test set: 0.9221719457013575
#
# Elapsed time: 234.26259517669678
#
# Iterazione 10
# train+validation: [   0    1    2 ... 9947 9948 9949] test: [ 9950  9951  9952 ... 11052 11053 11054]
# Modello: {'C': 0.001, 'kernel': 'linear'} accuracy: 0.9116582914572864
# Modello: {'C': 0.01, 'kernel': 'linear'} accuracy: 0.9176884422110553
# Modello: {'C': 0.1, 'kernel': 'linear'} accuracy: 0.9173869346733668
# Modello: {'C': 1.0, 'kernel': 'linear'} accuracy: 0.9176884422110553
# Modello: {'C': 10.0, 'kernel': 'linear'} accuracy: 0.9176884422110553
# Modello: {'C': 100.0, 'kernel': 'linear'} accuracy: 0.9180904522613065
# Modello: {'C': 1000.0, 'kernel': 'linear'} accuracy: 0.9174874371859296
# Miglior modello: {'C': 100.0, 'kernel': 'linear'} con score sul test set: 0.9276018099547512
#
# Elapsed time: 253.6658651828766
#
# Total elapsed time: 3024.9317808151245

# %%
print(results,"\n")
flag=False
duplicates=[]
tot=0
for x in results:
    tot=tot+results[x]['occurrency']
occ=0
best=None
for key in results:
    if results[key]['occurrency']>occ:
        occ=results[key]['occurrency']
        best=key
        testscores=results[key]['tests']
    elif results[key]['occurrency']==occ:
        flag=True
        duplicates.append(key)
print(best,"occorre",occ,"volte su",tot,".\nMedia dei test score:",np.mean(testscores))
if flag:
    print("Ci sono più modelli con la stessa occorrenza:")
    for x in duplicates:
        print(x,"occorre",results[x]['occurrency'],"volte su",tot,".\nMedia dei test score:",np.mean(results[x]['tests']))
# Out:
# {"{'C': 1.0, 'kernel': 'linear'}": {'occurrency': 3, 'tests': [0.9159132007233273, 0.9177215189873418, 0.9213381555153707]}, "{'C': 10.0, 'kernel': 'linear'}": {'occurrency': 1, 'tests': [0.9222423146473779]}, "{'C': 1000.0, 'kernel': 'linear'}": {'occurrency': 2, 'tests': [0.9041591320072333, 0.8995475113122172]}, "{'C': 100.0, 'kernel': 'linear'}": {'occurrency': 3, 'tests': [0.9266968325791856, 0.9230769230769231, 0.9276018099547512]}, "{'C': 0.1, 'kernel': 'linear'}": {'occurrency': 1, 'tests': [0.9221719457013575]}}
#
# {'C': 1.0, 'kernel': 'linear'} occorre 3 volte su 10 .
# Media dei test score: 0.9183242917420132
# Ci sono più modelli con la stessa occorrenza:
# {'C': 100.0, 'kernel': 'linear'} occorre 3 volte su 10 .
# Media dei test score: 0.9257918552036198

# %%
print(np.var([0.9159132007233273, 0.9177215189873418, 0.9213381555153707]))
print(np.var([0.9266968325791856, 0.9230769230769231, 0.9276018099547512]))
# Out:
# 5.086689912839577e-06
# 3.821925567999536e-06
